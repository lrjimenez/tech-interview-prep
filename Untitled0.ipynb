# %% [markdown]
# <a href="https://colab.research.google.com/github/lrjimenez/tech-interview-prep/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def find_max(nums):
    largest = nums[0]
    for n in nums:
      if n > largest:
          largest = n
    return largest
print(find_max([3,9,2,7]))
# Out:
# 9
